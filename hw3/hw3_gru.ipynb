# %% [markdown]
# # Speech Denoising Using GRU

# %% [markdown]
# ### Imports

# %%
import numpy as np
import librosa
import os
import tensorflow as tf
import tensorflow.keras.layers as layers
# Out:
# /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### Paths

# %%
train_path = "./homework3/tr/"
test_path = "./homework3/te/"
val_path = "./homework3/v/"

# %% [markdown]
# ## Training

# %% [markdown]
# ### Training Files List

# %%
trainList = os.listdir(train_path)
trainList.sort()

# %% [markdown]
# ### Create Lists

# %% [markdown]
# Create List containing all Noise Signals

# %%
noise_train = []
# maxi = 0  
for i in range(1200):
    s, sr = librosa.load(train_path+trainList[i], sr=None)
    S = librosa.stft(s, n_fft=1024, hop_length=512)
    S = np.abs(S)
    pad = np.zeros((513, 178))
    pad[:, :S.shape[1]] = S 
    noise_train.append(pad.T)

# %% [markdown]
# Create List containing all Clean Signals

# %%
clean_train = []
for i in range(1200, 2400):
    s, sr = librosa.load(train_path+trainList[i], sr=None)
    S = librosa.stft(s, n_fft=1024, hop_length=512)
    S = np.abs(S)
    pad = np.zeros((513, 178))
    pad[:, :S.shape[1]] = S 
    clean_train.append(pad.T)

# %% [markdown]
# Create List containing all Noisy Signals

# %%
noisy_train = []
for i in range(2400, 3600):
    s, sr = librosa.load(train_path+trainList[i], sr=None)
    S = librosa.stft(s, n_fft=1024, hop_length=512)
    S = np.abs(S)
    pad = np.zeros((513, 178))
    pad[:, :S.shape[1]] = S 
    noisy_train.append(pad.T)

# %% [markdown]
# ### Calculate IBM Mask

# %%
def ibm(clean, noise):
    
    ibm_mask = np.zeros((clean.shape))
    ibm_mask[clean > noise] = 1
    
    return ibm_mask

# %% [markdown]
# Create List containing all IBM Masks

# %%
ibm_train = []
for i in range(1200):
    ibm_mask = ibm(clean_train[i], noise_train[i])
    ibm_train.append(ibm_mask)

# %% [markdown]
# ### Create model

# %%
def gru_model():
    model = tf.keras.Sequential();
    model.add(layers.GRU(513, return_sequences=True))
    model.add(layers.Dropout(rate = 0.2))
    
    model.add(layers.GRU(513, return_sequences=True))
    model.add(layers.Dropout(rate = 0.2))
    
    model.add(layers.Dense(513, activation='sigmoid'))
    return model

# %% [markdown]
# ### Create a keras model object

# %%
model = gru_model()

# %% [markdown]
# Stacking stft frames to get dimensions as number_of_files x segments x 513

# %%
new_ibm_train = np.stack(ibm_train)
new_noisy_train = np.stack(noisy_train)

# %%
new_ibm_train.shape
# Out:
# (1200, 178, 513)

# %% [markdown]
# ### Compile the Model and Start Training

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(), loss = tf.keras.losses.BinaryCrossentropy())
model.fit(new_noisy_train, new_ibm_train, epochs=20, batch_size=10)
# Out:
# WARNING:tensorflow:From /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /home/rushabh/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 1200/1200 [==============================] - 58s 49ms/sample - loss: 0.4038
# Epoch 2/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.3050
# Epoch 3/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.2790
# Epoch 4/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.2618
# Epoch 5/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.2527
# Epoch 6/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.2441
# Epoch 7/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.2381
# Epoch 8/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.2305
# Epoch 9/20
# 1200/1200 [==============================] - 46s 38ms/sample - loss: 0.2265
# Epoch 10/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.2214
# Epoch 11/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.2170
# Epoch 12/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.2154
# Epoch 13/20
# 1200/1200 [==============================] - 45s 38ms/sample - loss: 0.2125
# Epoch 14/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.2077
# Epoch 15/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.2049
# Epoch 16/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.2014
# Epoch 17/20
# 1200/1200 [==============================] - 44s 37ms/sample - loss: 0.2003
# Epoch 18/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.1972
# Epoch 19/20
# 1200/1200 [==============================] - 45s 37ms/sample - loss: 0.1930
# Epoch 20/20
# 1200/1200 [==============================] - 46s 38ms/sample - loss: 0.1941

# %% [markdown]
# ## Validation

# %% [markdown]
# Training Files List

# %%
valList = os.listdir(val_path)
valList.sort()

# %% [markdown]
# ### Create Lists for Validation

# %% [markdown]
# Create List containing all Noise Signals

# %%
noise_val_abs = []
noise_val = []

for i in range(1200):
    s, sr = librosa.load(val_path+valList[i], sr=None)
    S = librosa.stft(s, n_fft=1024, hop_length=512)

    pad = np.zeros((513, 178))
    pad[:, :S.shape[1]] = S
    
    pad = pad.T
    
    abs_value = np.abs(pad)
    
    noise_val.append(pad) 
    noise_val_abs.append(abs_value)
# Out:
# /home/rushabh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:9: ComplexWarning: Casting complex values to real discards the imaginary part
#   if __name__ == '__main__':

# %% [markdown]
# Create List containing all Clean Signals

# %%
clean_val = []
clean_val_abs = []

# maxi = 0  
for i in range(1200, 2400):
    s, sr = librosa.load(val_path+valList[i], sr=None)
    S = librosa.stft(s, n_fft=1024, hop_length=512)

    pad = np.zeros((513, 178))
    pad[:, :S.shape[1]] = S
    
    pad = pad.T
    abs_value = np.abs(pad)
    
    clean_val.append(S) 
    clean_val_abs.append(abs_value)
# Out:
# /home/rushabh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: ComplexWarning: Casting complex values to real discards the imaginary part
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Create List containing all Noisy Signals

# %%
noisy_val = []
noisy_val_abs = []

# maxi = 0  
for i in range(2400, 3600):
    s, sr = librosa.load(val_path+valList[i], sr=None)
    S = librosa.stft(s, n_fft=1024, hop_length=512)

    pad = np.zeros((513, 178))
    pad[:, :S.shape[1]] = S
    
    pad = pad.T
    abs_value = np.abs(pad)
    
    noisy_val.append(pad) 
    noisy_val_abs.append(abs_value)
# Out:
# /home/rushabh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: ComplexWarning: Casting complex values to real discards the imaginary part
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# Create List containing all IBM Masks

# %%
ibm_val = []
for i in range(1200):
    ibm_mask = ibm(clean_val_abs[i], noise_val_abs[i])
    ibm_val.append(ibm_mask)

# %% [markdown]
# Stacking stft frames to get dimensions as number_of_files x segments x 513

# %%
new_ibm_val = np.stack(ibm_val)
new_noisy_val = np.stack(noisy_val_abs)

# %%
new_ibm_val.shape
# Out:
# (1200, 178, 513)

# %%
new_noisy_val.shape
# Out:
# (1200, 178, 513)

# %% [markdown]
# ### Check Validation Loss

# %%
model.evaluate(new_noisy_val, new_ibm_val, batch_size=10)
# Out:
# 1200/1200 [==============================] - 15s 12ms/sample - loss: 0.2678
# 0.2678025668486953

# %% [markdown]
# ### Get the predicted IBM masks for Validation Set

# %%
Getmasks = model.predict(new_noisy_val, batch_size=10)

# %% [markdown]
# Stacking stft frames to get dimensions as number_of_files x segments x 513

# %%
new_noisy_val_complex = np.stack(noisy_val)

# %%
new_noisy_val_complex.shape
# Out:
# (1200, 178, 513)

# %% [markdown]
# ### Multiply the IBM Mask with Noisy Speech to get Clean Speech

# %%
S_recon = np.multiply(masks, new_noisy_val_complex)

# %% [markdown]
# ### Calculate SNR

# %%
def snr(clean, recon):
    print(clean.shape)
    recon = recon[:clean.shape[0]]
    return 10*np.log10(np.sum(clean**2)/np.sum(clean - recon)**2)

# %%
clean_val[0].shape
# Out:
# (513, 65)

# %% [markdown]
# ### Calculating Average SNR of the Validation Set

# %%
avg_snr = 0
for i in range(1200):
    print(i)
    c = librosa.istft(clean_val[i], win_length=1024, hop_length=512)
    r = librosa.istft(S_recon[i].T, win_length=1024, hop_length=512)
    new_snr = snr(c, r)
    print(new_snr)
    avg_snr += new_snr
    
avg_snr /= 1200
# Out:
# 0
# (32768,)
# 17.086732134715493
# 1
# (32768,)
# 19.97048753021257
# 2
# (32768,)
# 17.31621421682287
# 3
# (32768,)
# 25.257293242610324
# 4
# (32768,)
# 17.624635251910068
# 5
# (32768,)
# 17.80715238059592
# 6
# (32768,)
# 17.916363544140435
# 7
# (32768,)
# 37.65166943441137
# 8
# (32768,)
# 18.61337045407922
# 9
# (32768,)
# 15.096537765239553
# 10
# (66048,)
# 19.646598221712537
# 11
# (66048,)
# 27.537725528410974
# 12
# (66048,)
# 19.192541517192243
# 13
# (66048,)
# 24.48793721860271
# 14
# (66048,)
# 19.269260728956073
# 15
# (66048,)
# 27.24476161492956
# 16
# (66048,)
# 19.78179607358945
# 17
# (66048,)
# 49.205529700536644
# 18
# (66048,)
# 13.70239142585839
# 19
# (66048,)
# 18.203415798324723
# 20
# (37888,)
# 23.345084525726723
# 21
# (37888,)
# 25.935868640971393
# 22
# (37888,)
# 17.44814039439405
# 23
# (37888,)
# 20.1628028138471
# 24
# (37888,)
# 21.55320410640347
# 25
# (37888,)
# 18.100370919114205
# 26
# (37888,)
# 19.169197475493746
# 27
# (37888,)
# 50.62604505767339
# 28
# (37888,)
# 26.880237539350468
# 29
# (37888,)
# 21.675413323741477
# 30
# (34816,)
# 65.70234510256921
# 31
# (34816,)
# 26.75749837269295
# 32
# (34816,)
# 29.220884103127418
# 33
# (34816,)
# 44.58216285170398
# 34
# (34816,)
# 23.2214926912146
# 35
# (34816,)
# 28.349826796714353
# 36
# (34816,)
# 22.070555174934775
# 37
# (34816,)
# 49.3477125411429
# 38
# (34816,)
# 23.88266747772517
# 39
# (34816,)
# 38.43634578010813
# 40
# (46592,)
# 29.125148091139383
# 41
# (46592,)
# 25.36533476210704
# 42
# (46592,)
# 12.960035412083668
# 43
# (46592,)
# 23.092725517710328
# 44
# (46592,)
# 18.303232397666502
# 45
# (46592,)
# 25.091743507390692
# 46
# (46592,)
# 26.7737192333877
# 47
# (46592,)
# 43.18528898550876
# 48
# (46592,)
# 30.212143829759764
# 49
# (46592,)
# 21.73962889772202
# 50
# (52224,)
# 11.80974368899781
# 51
# (52224,)
# 13.714047862309295
# 52
# (52224,)
# 49.82406215342351
# 53
# (52224,)
# 15.876088075183684
# 54
# (52224,)
# 11.70754088272349
# 55
# (52224,)
# 20.726426412957004
# 56
# (52224,)
# 14.579351179450084
# 57
# (52224,)
# 47.798027009691594
# 58
# (52224,)
# 9.745229943447548
# 59
# (52224,)
# 12.464329259851212
# 60
# (44032,)
# 13.909603036332738
# 61
# (44032,)
# 12.160053925923858
# 62
# (44032,)
# 42.39886503658251
# 63
# (44032,)
# 14.722305959919783
# 64
# (44032,)
# 11.449986282910448
# 65
# (44032,)
# 16.369165041111145
# 66
# (44032,)
# 16.00816425593162
# 67
# (44032,)
# 16.938933989218967
# 68
# (44032,)
# 14.068305953927137
# 69
# (44032,)
# 13.314988743444578
# 70
# (70656,)
# 21.076759394611415
# 71
# (70656,)
# 30.350185349518377
# 72
# (70656,)
# 12.387177889166235
# 73
# (70656,)
# 26.693002726027096
# 74
# (70656,)
# 18.695687251565367
# 75
# (70656,)
# 20.8056753526576
# 76
# (70656,)
# 28.435954834669978
# 77
# (70656,)
# 42.35138141078441
# 78
# (70656,)
# 18.354643408463044
# 79
# (70656,)
# 25.40837978472112
# 80
# (39424,)
# 22.658102209084177
# 81
# (39424,)
# 39.11366701799869
# 82
# (39424,)
# 22.54507905298205
# 83
# (39424,)
# 28.71743225519214
# 84
# (39424,)
# 26.914755583943865
# 85
# (39424,)
# 29.289311808968893
# 86
# (39424,)
# 32.65819118755537
# 87
# (39424,)
# 38.28406841905989
# 88
# (39424,)
# 23.587877520569332
# 89
# (39424,)
# 28.114337422639956
# 90
# (40448,)
# 12.865503109905458
# 91
# (40448,)
# 13.09272998519961
# 92
# (40448,)
# 8.910090094723895
# 93
# (40448,)
# 15.666368907319711
# 94
# (40448,)
# 14.166715933386069
# 95
# (40448,)
# 18.696806253517302
# 96
# (40448,)
# 16.494836101629758
# 97
# (40448,)
# 40.224814347871025
# 98
# (40448,)
# 13.435295036688181
# 99
# (40448,)
# 14.770211404208059
# 100
# (71680,)
# 20.487789337918638
# 101
# (71680,)
# 15.173737238910993
# 102
# (71680,)
# 14.338914101670339
# 103
# (71680,)
# 27.379714826228707
# 104
# (71680,)
# 16.935034251642985
# 105
# (71680,)
# 18.94775783049188
# 106
# (71680,)
# 32.25403212571439
# 107
# (71680,)
# 38.970234573504094
# 108
# (71680,)
# 15.738270840546768
# 109
# (71680,)
# 14.906359931493679
# 110
# (34816,)
# 12.466774504917318
# 111
# (34816,)
# 17.094929086545797
# 112
# (34816,)
# 10.026822020211982
# 113
# (34816,)
# 15.214401236571957
# 114
# (34816,)
# 14.17187669704957
# 115
# (34816,)
# 15.577209247836398
# 116
# (34816,)
# 14.29785226251964
# 117
# (34816,)
# 43.5404155438367
# 118
# (34816,)
# 16.404762950122105
# 119
# (34816,)
# 12.443306441945069
# 120
# (39424,)
# 21.266525455269303
# 121
# (39424,)
# 18.800641728259137
# 122
# (39424,)
# 13.841744366262962
# 123
# (39424,)
# 21.753672938562456
# 124
# (39424,)
# 17.9720455956849
# 125
# (39424,)
# 18.757226709217804
# 126
# (39424,)
# 33.52230468963679
# 127
# (39424,)
# 22.284601807515916
# 128
# (39424,)
# 20.095198391839084
# 129
# (39424,)
# 20.890874220061168
# 130
# (38912,)
# 36.94301681244433
# 131
# (38912,)
# 42.28299071459675
# 132
# (38912,)
# 25.01169079223512
# 133
# (38912,)
# 33.57461710901123
# 134
# (38912,)
# 45.91005064185413
# 135
# (38912,)
# 20.760121940551354
# 136
# (38912,)
# 23.45538844508802
# 137
# (38912,)
# 29.739120472321716
# 138
# (38912,)
# 22.371684045865617
# 139
# (38912,)
# 53.033379822889984
# 140
# (66560,)
# 42.26925182468428
# 141
# (66560,)
# 42.59713299257865
# 142
# (66560,)
# 12.70268810580302
# 143
# (66560,)
# 27.12860162267704
# 144
# (66560,)
# 32.9344100642036
# 145
# (66560,)
# 24.138785200647085
# 146
# (66560,)
# 29.696559910921753
# 147
# (66560,)
# 31.69363217004132
# 148
# (66560,)
# 18.04509047648707
# 149
# (66560,)
# 35.87402087570637
# 150
# (39424,)
# 33.47766958843876
# 151
# (39424,)
# 31.83454774492395
# 152
# (39424,)
# 19.558014491517824
# 153
# (39424,)
# 35.69564782121998
# 154
# (39424,)
# 31.473465079918334
# 155
# (39424,)
# 28.118899554031426
# 156
# (39424,)
# 38.292183776220256
# 157
# (39424,)
# 33.70368860086151
# 158
# (39424,)
# 36.79343123208074
# 159
# (39424,)
# 26.13675408022828
# 160
# (39936,)
# 18.727568558459733
# 161
# (39936,)
# 16.489070708329628
# 162
# (39936,)
# 14.916854421713929
# 163
# (39936,)
# 19.201872608368195
# 164
# (39936,)
# 13.461521954874542
# 165
# (39936,)
# 32.10796222505523
# 166
# (39936,)
# 21.19921105193039
# 167
# (39936,)
# 26.590889554249294
# 168
# (39936,)
# 17.810451737173935
# 169
# (39936,)
# 14.635055799943682
# 170
# (47616,)
# 25.623387222769928
# 171
# (47616,)
# 21.01561915747279
# 172
# (47616,)
# 13.442389924272275
# 173
# (47616,)
# 26.75520535897895
# 174
# (47616,)
# 25.813169059575163
# 175
# (47616,)
# 16.14934021945832
# 176
# (47616,)
# 30.099475035670768
# 177
# (47616,)
# 22.904553672966003
# 178
# (47616,)
# 24.694706664777218
# 179
# (47616,)
# 33.89963369274697
# 180
# (54784,)
# 28.40953258800581
# 181
# (54784,)
# 41.302040565528
# 182
# (54784,)
# 18.62252695782959
# 183
# (54784,)
# 31.44070224181021
# 184
# (54784,)
# 21.905419371347186
# 185
# (54784,)
# 31.209311853382896
# 186
# (54784,)
# 98.14951516237866
# 187
# (54784,)
# 36.7947184773046
# 188
# (54784,)
# 47.86101961156754
# 189
# (54784,)
# 24.84331221266222
# 190
# (44544,)
# 44.07674707728195
# 191
# (44544,)
# 37.883846197871534
# 192
# (44544,)
# 13.192281366354608
# 193
# (44544,)
# 20.841097526101336
# 194
# (44544,)
# 26.900706895761857
# 195
# (44544,)
# 25.627928903697523
# 196
# (44544,)
# 33.66864606871937
# 197
# (44544,)
# 42.56889434106626
# 198
# (44544,)
# 18.807091222565738
# 199
# (44544,)
# 31.240557572394128
# 200
# (53760,)
# 25.26040022467214
# 201
# (53760,)
# 26.350018661769184
# 202
# (53760,)
# 15.087386770689124
# 203
# (53760,)
# 41.34958931880122
# 204
# (53760,)
# 26.757568321886502
# 205
# (53760,)
# 24.90361200397759
# 206
# (53760,)
# 31.39990907590706
# 207
# (53760,)
# 35.768726190023614
# 208
# (53760,)
# 22.390518200035636
# 209
# (53760,)
# 25.22600785169347
# 210
# (83968,)
# 11.95406609981388
# 211
# (83968,)
# 11.330600509820702
# 212
# (83968,)
# 30.940012303841677
# 213
# (83968,)
# 16.773873442457027
# 214
# (83968,)
# 10.520800976849126
# 215
# (83968,)
# 16.609229502802695
# 216
# (83968,)
# 11.848954403738958
# 217
# (83968,)
# 28.43231956819882
# 218
# (83968,)
# 12.616200357354167
# 219
# (83968,)
# 11.417712842964567
# 220
# (45568,)
# 14.345823615631028
# 221
# (45568,)
# 16.258136905437592
# 222
# (45568,)
# 16.261597281491103
# 223
# (45568,)
# 18.977866455903182
# 224
# (45568,)
# 11.285240342731067
# 225
# (45568,)
# 26.014137734521313
# 226
# (45568,)
# 12.236234186932771
# 227
# (45568,)
# 28.07668664600396
# 228
# (45568,)
# 11.92589526929199
# 229
# (45568,)
# 12.194955868672048
# 230
# (65024,)
# 15.586558361490875
# 231
# (65024,)
# 16.17496623686745
# 232
# (65024,)
# 11.510333557376281
# 233
# (65024,)
# 17.23187206721612
# 234
# (65024,)
# 14.571942697325158
# 235
# (65024,)
# 24.57761611032186
# 236
# (65024,)
# 19.07522640023914
# 237
# (65024,)
# 27.742143836196046
# 238
# (65024,)
# 12.270507094185717
# 239
# (65024,)
# 15.426880156141042
# 240
# (67072,)
# 14.41085553880435
# 241
# (67072,)
# 16.867880963884456
# 242
# (67072,)
# 35.60429614018222
# 243
# (67072,)
# 16.222817435687617
# 244
# (67072,)
# 12.664931326478683
# 245
# (67072,)
# 17.982580478417564
# 246
# (67072,)
# 14.209719772392859
# 247
# (67072,)
# 25.807077863931646
# 248
# (67072,)
# 15.851523052851437
# 249
# (67072,)
# 15.823405776299651
# 250
# (50688,)
# 15.545782915796472
# 251
# (50688,)
# 24.90341832839806
# 252
# (50688,)
# 22.025960695546768
# 253
# (50688,)
# 20.51965959815853
# 254
# (50688,)
# 15.093973290375509
# 255
# (50688,)
# 15.576137006843103
# 256
# (50688,)
# 17.104452304655922
# 257
# (50688,)
# 21.12470406668122
# 258
# (50688,)
# 13.76319396634615
# 259
# (50688,)
# 19.368838545825348
# 260
# (52224,)
# 12.387111328344107
# 261
# (52224,)
# 13.80228640736004
# 262
# (52224,)
# 14.424755554160352
# 263
# (52224,)
# 17.27526627270121
# 264
# (52224,)
# 11.569642088757714
# 265
# (52224,)
# 15.845296061701838
# 266
# (52224,)
# 12.671415941512258
# 267
# (52224,)
# 23.759569033284578
# 268
# (52224,)
# 10.722961409407546
# 269
# (52224,)
# 14.176663490005172
# 270
# (73216,)
# 11.64899083572299
# 271
# (73216,)
# 12.49668676644992
# 272
# (73216,)
# 8.238692456894672
# 273
# (73216,)
# 16.365391511131957
# 274
# (73216,)
# 12.413262920678697
# 275
# (73216,)
# 13.763552176021516
# 276
# (73216,)
# 13.398906350059814
# 277
# (73216,)
# 23.670062699237793
# 278
# (73216,)
# 18.70687335959172
# 279
# (73216,)
# 11.48743472442093
# 280
# (56320,)
# 14.416855061520046
# 281
# (56320,)
# 16.68572211089283
# 282
# (56320,)
# 16.51697794551702
# 283
# (56320,)
# 12.09758715712081
# 284
# (56320,)
# 13.262170057321264
# 285
# (56320,)
# 16.487161766890633
# 286
# (56320,)
# 14.934068953496606
# 287
# (56320,)
# 24.44554485662694
# 288
# (56320,)
# 14.441938627945287
# 289
# (56320,)
# 13.274439800489484
# 290
# (73216,)
# 13.405945397810896
# 291
# (73216,)
# 14.321472847601115
# 292
# (73216,)
# 12.332714354961265
# 293
# (73216,)
# 12.982013552037504
# 294
# (73216,)
# 13.156495455555483
# 295
# (73216,)
# 15.955045292529661
# 296
# (73216,)
# (51200,)
# 18.016774553121515
# 371
# (51200,)
# 26.80984237981884
# 372
# (51200,)
# 44.119504266416236
# 373
# (51200,)
# 20.935105591237196
# 374
# (51200,)
# 20.627225261720557
# 375
# (51200,)
# 18.996848717649936
# 376
# (51200,)
# 17.0812298366609
# 377
# (51200,)
# 23.41240698912092
# 378
# (51200,)
# 19.238409354028718
# 379
# (51200,)
# 19.24746979480632
# 380
# (33792,)
# 22.460385741125002
# 381
# (33792,)
# 60.43862475768073
# 382
# (33792,)
# 17.130299838892135
# 383
# (33792,)
# 38.587796538647304
# 384
# (33792,)
# 33.51696971995758
# 385
# (33792,)
# 21.77259436514339
# 386
# (33792,)
# 30.025029948417735
# 387
# (33792,)
# 25.536478611631917
# 388
# (33792,)
# 26.537103014416495
# 389
# (33792,)
# 26.950178101953377
# 390
# (37376,)
# 17.671756793878433
# 391
# (37376,)
# 12.636134038712118
# 392
# (37376,)
# 32.087449692868375
# 393
# (37376,)
# 16.77743714208454
# 394
# (37376,)
# 12.785652086065475
# 395
# (37376,)
# 20.048456912069543
# 396
# (37376,)
# 13.611036215850943
# 397
# (37376,)
# 16.27497533318458
# 398
# (37376,)
# 13.613665399057158
# 399
# (37376,)
# 18.15819310903666
# 400
# (53760,)
# 16.49626811303203
# 401
# (53760,)
# 19.127429081659383
# 402
# (53760,)
# 22.889544834063674
# 403
# (53760,)
# 17.237251501705128
# 404
# (53760,)
# 14.258207385921217
# 405
# (53760,)
# 21.924186389672474
# 406
# (53760,)
# 17.202445104418377
# 407
# (53760,)
# 25.809659727130065
# 408
# (53760,)
# 12.28160959672863
# 409
# (53760,)
# 16.063899104049135
# 410
# (53248,)
# 18.400400874203818
# 411
# (53248,)
# 23.944808126566663
# 412
# (53248,)
# 46.04385245406297
# 413
# (53248,)
# 25.426623125601232
# 414
# (53248,)
# 14.362039598631615
# 415
# (53248,)
# 27.61519570386077
# 416
# (53248,)
# 25.92830484570824
# 417
# (53248,)
# 17.752644410572522
# 418
# (53248,)
# 17.59447975541827
# 419
# (53248,)
# 19.704160252057726
# 420
# (39936,)
# 13.97687429834223
# 421
# (39936,)
# 17.03663516376912
# 422
# (39936,)
# 24.526462619091358
# 423
# (39936,)
# 18.873739686245894
# 424
# (39936,)
# 14.600992126778056
# 425
# (39936,)
# 28.096097834135012
# 426
# (39936,)
# 18.68405330494375
# 427
# (39936,)
# 24.169111457099493
# 428
# (39936,)
# 11.051887935872575
# 429
# (39936,)
# 13.911625269693646
# 430
# (50176,)
# 14.681992786816021
# 431
# (50176,)
# 16.60210579370743
# 432
# (50176,)
# 21.185109816678676
# 433
# (50176,)
# 17.545538244423458
# 434
# (50176,)
# 11.037517564775053
# 435
# (50176,)
# 16.757072328091546
# 436
# (50176,)
# 17.472716026263065
# 437
# (50176,)
# 29.518121014017325
# 438
# (50176,)
# 12.973681979182071
# 439
# (50176,)
# 16.47523546421919
# 440
# (52224,)
# 19.565476902335877
# 441
# (52224,)
# 18.78308871303937
# 442
# (52224,)
# 13.100415331687964
# 443
# (52224,)
# 21.014830344460922
# 37.29429308075501
# 740
# (71168,)
# 37.25356858211177
# 741
# (71168,)
# 29.985021104158296
# 742
# (71168,)
# 20.099121208981046
# 743
# (71168,)
# 28.28347035289006
# 744
# (71168,)
# 25.136763416586444
# 745
# (71168,)
# 25.71911189443748
# 746
# (71168,)
# 21.394314601736035
# 747
# (71168,)
# 47.55646317847895
# 748
# (71168,)
# 44.005280319821125
# 749
# (71168,)
# 33.47793943457166
# 750
# (37376,)
# 21.07716055901197
# 751
# (37376,)
# 23.91128193733315
# 752
# (37376,)
# 15.586785644572611
# 753
# (37376,)
# 20.338993607566607
# 754
# (37376,)
# 21.56130465604599
# 755
# (37376,)
# 23.37558217013195
# 756
# (37376,)
# 20.916864216733153
# 757
# (37376,)
# 35.194042809038685
# 758
# (37376,)
# 19.018984578146352
# 759
# (37376,)
# 22.228267783803986
# 760
# (48128,)
# 57.60433155279652
# 761
# (48128,)
# 30.56531598347945
# 762
# (48128,)
# 20.105679849819325
# 763
# (48128,)
# 29.289917069708817
# 764
# (48128,)
# 33.347970468313385
# 765
# (48128,)
# 29.263134036554888
# 766
# (48128,)
# 29.253360007650777
# 767
# (48128,)
# 30.972977535098813
# 768
# (48128,)
# 17.053170683908856
# 769
# (48128,)
# 40.68422721699551
# 770
# (37376,)
# 53.51356148808939
# 771
# (37376,)
# 37.19232410471016
# 772
# (37376,)
# 23.391952426575763
# 773
# (37376,)
# 23.05989806961525
# 774
# (37376,)
# 44.00762783630147
# 775
# (37376,)
# 22.179943047049086
# 776
# (37376,)
# 27.96229680882444
# 777
# (37376,)
# 37.322107218609084
# 778
# (37376,)
# 14.419137693715864
# 779
# (37376,)
# 28.772857442957296
# 780
# (35328,)
# 44.868523824662525
# 781
# (35328,)
# 37.92074708826928
# 782
# (35328,)
# 35.68622984972227
# 783
# (35328,)
# 37.37900143585441
# 784
# (35328,)
# 40.28059916997245
# 785
# (35328,)
# 33.05963377509742
# 786
# (35328,)
# 32.9354756115993
# 787
# (35328,)
# 34.62373959033806
# 788
# (35328,)
# 24.006426376006303
# 789
# (35328,)
# 34.797455440132104
# 790
# (45568,)
# 20.886526097854752
# 791
# (45568,)
# 23.736309018763897
# 792
# (45568,)
# 31.296076820123908
# 793
# (45568,)
# 61.017648937638036
# 794
# (45568,)
# 19.77774723036021
# 795
# (45568,)
# 19.845324578376527
# 796
# (45568,)
# 21.015140552108935
# 797
# (45568,)
# 36.17960661111632
# 798
# (45568,)
# 20.858376856488924
# 799
# (45568,)
# 24.391176330570833
# 800
# (35840,)
# 17.19378474297551
# 801
# (35840,)
# 19.04369635182901
# 802
# (35840,)
# 12.815459868119188
# 803
# (35840,)
# 23.560783316536188
# 804
# (35840,)
# 18.526882505543654
# 805
# (35840,)
# 16.303396513458715
# 806
# (35840,)
# 37.26827419453442
# 807
# (35840,)
# 41.596941959997544
# 808
# (35840,)
# 26.414624582902118
# 809
# (35840,)
# 17.74375656982295
# 810
# (27136,)
# 26.18838041226482
# 811
# (27136,)
# 31.002582903915602
# 812
# (27136,)
# 29.504395860993824
# 813
# 961
# (86528,)
# 7.3182661351569775
# 962
# (86528,)
# 8.696573551802862
# 963
# (86528,)
# 10.285771508814058
# 964
# (86528,)
# 7.117361229347875
# 965
# (86528,)
# 13.766930863676867
# 966
# (86528,)
# 10.5457133418202
# 967
# (86528,)
# 44.509949317218904
# 968
# (86528,)
# 5.149528836866166
# 969
# (86528,)
# 6.399747412019703
# 970
# (55808,)
# 45.557903935631934
# 971
# (55808,)
# 18.214312735934836
# 972
# (55808,)
# 12.622376600863891
# 973
# (55808,)
# 30.36170545816091
# 974
# (55808,)
# 29.859685368167437
# 975
# (55808,)
# 23.4790643275069
# 976
# (55808,)
# 19.946452385508557
# 977
# (55808,)
# 31.349195176143493
# 978
# (55808,)
# 24.762344668465502
# 979
# (55808,)
# 17.597298493800714
# 980
# (66048,)
# 13.341040875300326
# 981
# (66048,)
# 23.737754769849136
# 982
# (66048,)
# 15.372171127858037
# 983
# (66048,)
# 17.683331780428343
# 984
# (66048,)
# 15.064665756878444
# 985
# (66048,)
# 22.51875561878243
# 986
# (66048,)
# 12.943647627530488
# 987
# (66048,)
# 23.60764417911094
# 988
# (66048,)
# 15.320798496381393
# 989
# (66048,)
# 12.251033085240914
# 990
# (54784,)
# 34.71874017207212
# 991
# (54784,)
# 35.322584240696855
# 992
# (54784,)
# 19.219751023152796
# 993
# (54784,)
# 41.35688025853198
# 994
# (54784,)
# 32.8745358848863
# 995
# (54784,)
# 10.96952579048903
# 996
# (54784,)
# 14.174138799979206
# 997
# (54784,)
# 9.730038846380399
# 998
# (54784,)
# 21.61095600443931
# 999
# (54784,)
# 23.209565171179143
# 1000
# (50688,)
# 14.569982002929622
# 1001
# (50688,)
# 15.406487883156842
# 1002
# (50688,)
# 16.27027458854164
# 1003
# (50688,)
# 21.674460241625084
# 1004
# (50688,)
# 13.370509416529408
# 1005
# (50688,)
# 18.27250944801159
# 1006
# (50688,)
# 14.469130866708035
# 1007
# (50688,)
# 30.03026625413205
# 1008
# (50688,)
# 11.768936483397994
# 1009
# (50688,)
# 14.959155179329562
# 1010
# (31232,)
# 31.652599619515392
# 1011
# (31232,)
# 50.82316217482056
# 1012
# (31232,)
# 17.588556311758357
# 1013
# (31232,)
# 24.18758253514057
# 1014
# (31232,)
# 33.559736357295336
# 1015
# (31232,)
# 37.7361217767542
# 1016
# (31232,)
# 24.746938077830695
# 1017
# (31232,)
# 30.612603372996364
# 1018
# (31232,)
# 25.12415096703187
# 1019
# (31232,)
# 24.095276838733515
# 1020
# (48640,)
# 34.44778716141897
# 1021
# (48640,)
# 31.7455651822129
# 1022
# (48640,)
# 13.238346100001461
# 1023
# (48640,)
# 26.03661727010718
# 1024
# (48640,)
# 30.307843903874947
# 1025
# (48640,)
# 33.66997286691586
# 1026
# (48640,)
# 46.027381978642566
# 1027
# (48640,)
# 34.360573336363714
# 1028
# (48640,)
# 31.701759020210297
# 1029
# (48640,)
# 29.059480264541676
# 1030
# (45568,)
# 22.14738410354514
# 1031
# (45568,)
# 20.314350956585088
# 1032
# (45568,)
# 34.928806231672034
# 1033
# (37376,)
# 23.47144010315743
# 1175
# (37376,)
# 24.925239462554323
# 1176
# (37376,)
# 24.06262420013658
# 1177
# (37376,)
# 27.411564061209617
# 1178
# (37376,)
# 21.710600926450994
# 1179
# (37376,)
# 23.93795916171365
# 1180
# (59392,)
# 21.138940711362523
# 1181
# (59392,)
# 25.153478550067927
# 1182
# (59392,)
# 14.347434653791689
# 1183
# (59392,)
# 24.19453216748748
# 1184
# (59392,)
# 20.43085037232155
# 1185
# (59392,)
# 31.16095088296487
# 1186
# (59392,)
# 19.62932646678227
# 1187
# (59392,)
# 40.366213736965534
# 1188
# (59392,)
# 18.36955432551412
# 1189
# (59392,)
# 20.24032572517223
# 1190
# (45568,)
# 19.11064231668151
# 1191
# (45568,)
# 19.77370669683175
# 1192
# (45568,)
# 15.388748297307222
# 1193
# (45568,)
# 23.89947046035246
# 1194
# (45568,)
# 19.4499760837885
# 1195
# (45568,)
# 22.90277687684352
# 1196
# (45568,)
# 27.413701856056335
# 1197
# (45568,)
# 48.04185734018964
# 1198
# (45568,)
# 32.87271220618454
# 1199
# (45568,)
# 27.76189930420265

# %%
print(avg_snr)
# Out:
# 24.008218650585924

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Testing Files List

# %%
testList = os.listdir(test_path)
testList.sort()

# %%
len(testList)
# Out:
# 400

# %% [markdown]
# ### Create List containing all Noisy Signals

# %%
noisy_test_abs = []
noisy_test = []

for i in range(400):
    s, sr = librosa.load(test_path+testList[i], sr=None)
    S = librosa.stft(s, n_fft=1024, hop_length=512)

    pad = np.zeros((513, 195))
    pad[:, :S.shape[1]] = S
    
    pad = pad.T
    
    abs_value = np.abs(pad)
    
    noisy_test.append(pad) 
    noisy_test_abs.append(abs_value)
# Out:
# /home/rushabh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:9: ComplexWarning: Casting complex values to real discards the imaginary part
#   if __name__ == '__main__':

# %% [markdown]
# Stacking stft frames to get dimensions as number_of_files x segments x 513

# %%
new_noisy_test_abs = np.stack(noisy_test_abs)

# %% [markdown]
# ### Get the predicted IBM masks for the Test Set

# %%
masks = model.predict(new_noisy_test_abs, batch_size=10)

# %% [markdown]
# Stacking stft frames to get dimensions as number_of_files x segments x 513

# %%
new_noisy_test_complex = np.stack(noisy_test)

# %% [markdown]
# ### Multiply the IBM Mask with Noisy Speech to get Clean Speech

# %%
S_recon = np.multiply(masks, new_noisy_test_complex)

# %% [markdown]
# ### Save all the reconstructed files

# %%
save_path = './homework3/test_wav/'

# %% [markdown]
# Take inverse STFT and truncate the signals to the length of the original noisy signal and then save the corresponding signal

# %%
for i in range(400):
    s, sr = librosa.load(test_path+testList[i], sr=None)
    recon = librosa.istft(S_recon[i].T, win_length=1024, hop_length=512)
    recon = recon[:len(s)]
    librosa.output.write_wav(save_path+testList[i]+"_cleaned.wav", recon, sr)

# %% [markdown]
# ## Things Noticed
# I am getting a High SNR ~24. I thought the model was overfitting the data but then I generated the Clean Test Signals and I am getting a clear output.
# Also, if the model was overfitting I would get a High SNR just on the training set and not on the Validation Set
